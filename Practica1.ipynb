# %% [markdown]
# Mi usuario Gilhub es Domingobd

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
2 + 2
# esto es un comentario en una celda de código
# Out:
# 4

# %%
a = 35 - 8
a
# Out:
# 27

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
len("aprendizaje")
# Out:
# 11
